# %% [markdown]
# ## Time Series EDA

# %% [markdown]
# Time series involves in data processing with respect to time.

# %%
# !pip install pandas-datareader
# Out:
# ...
#      -------------------------------------- 109.5/109.5 kB 1.6 MB/s eta 0:00:00
# ...
# [notice] A new release of pip available: 22.2.2 -> 22.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas_datareader as pdr
import pandas as pd
from datetime import datetime

# %%
# !pip install yfinance
# Out:
# ...
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# conda-repo-cli 1.0.4 requires pathlib, which is not installed.
# anaconda-project 0.10.1 requires ruamel-yaml, which is not installed.
#
# [notice] A new release of pip available: 22.2.2 -> 22.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ...
#      -------------------------------------- 51.4/51.4 kB 219.0 kB/s eta 0:00:00
# ...
#      ---------------------------------------- 62.8/62.8 kB 1.7 MB/s eta 0:00:00
# ...
#      -------------------------------------- 128.2/128.2 kB 2.5 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 3.9/3.9 MB 1.7 MB/s eta 0:00:00
# ...
#      -------------------------------------- 499.4/499.4 kB 1.2 MB/s eta 0:00:00
# ...
#   Attempting uninstall: pytz
#     Found existing installation: pytz 2021.3
#     Uninstalling pytz-2021.3:
# ...

# %%
df_tesla = pdr.get_data_yahoo('TSLA',start="2019-08-13",end="2022-08-14")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_608/290783858.py in <module>
# ----> 1 df_tesla = pdr.get_data_yahoo('TSLA',start="2019-08-13",end="2022-08-14")
#
# ~\anaconda3\lib\site-packages\pandas_datareader\data.py in get_data_yahoo(*args, **kwargs)
#      78
#      79 def get_data_yahoo(*args, **kwargs):
# ---> 80     return YahooDailyReader(*args, **kwargs).read()
#      81
#      82
#
# ~\anaconda3\lib\site-packages\pandas_datareader\base.py in read(self)
#     251         # If a single symbol, (e.g., 'GOOG')
#     252         if isinstance(self.symbols, (string_types, int)):
# --> 253             df = self._read_one_data(self.url, params=self._get_params(self.symbols))
#     254         # Or multiple symbols, (e.g., ['GOOG', 'AAPL', 'MSFT'])
#     255         elif isinstance(self.symbols, DataFrame):
#
# ...

# %%
pdr.get_data_fred('GS10')
# Out:
#             GS10
# DATE
# 2018-02-01  2.86
# 2018-03-01  2.84
# 2018-04-01  2.87
# 2018-05-01  2.98
# 2018-06-01  2.91
# 2018-07-01  2.89
# 2018-08-01  2.89
# 2018-09-01  3.00
# 2018-10-01  3.15
# 2018-11-01  3.12
# 2018-12-01  2.83
# 2019-01-01  2.71
# 2019-02-01  2.68
# 2019-03-01  2.57
# 2019-04-01  2.53
# 2019-05-01  2.40
# 2019-06-01  2.07
# 2019-07-01  2.06
# 2019-08-01  1.63
# 2019-09-01  1.70
# 2019-10-01  1.71
# 2019-11-01  1.81
# 2019-12-01  1.86
# 2020-01-01  1.76
# 2020-02-01  1.50
# 2020-03-01  0.87
# 2020-04-01  0.66
# 2020-05-01  0.67
# 2020-06-01  0.73
# 2020-07-01  0.62
# 2020-08-01  0.65
# 2020-09-01  0.68
# 2020-10-01  0.79
# 2020-11-01  0.87
# 2020-12-01  0.93
# 2021-01-01  1.08
# 2021-02-01  1.26
# 2021-03-01  1.61
# 2021-04-01  1.64
# 2021-05-01  1.62
# 2021-06-01  1.52
# 2021-07-01  1.32
# 2021-08-01  1.28
# 2021-09-01  1.37
# 2021-10-01  1.58
# 2021-11-01  1.56
# 2021-12-01  1.47
# 2022-01-01  1.76
# 2022-02-01  1.93
# 2022-03-01  2.13
# 2022-04-01  2.75
# ...

# %%
pdr.get_data_fred('TSLA')
# Out:
# ---------------------------------------------------------------------------
# RemoteDataError                           Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_608/92778868.py in <module>
# ----> 1 pdr.get_data_fred('TSLA')
#
# ~\anaconda3\lib\site-packages\pandas_datareader\data.py in get_data_fred(*args, **kwargs)
#      70
#      71 def get_data_fred(*args, **kwargs):
# ---> 72     return FredReader(*args, **kwargs).read()
#      73
#      74
#
# ~\anaconda3\lib\site-packages\pandas_datareader\fred.py in read(self)
#      25         """
#      26         try:
# ---> 27             return self._read()
#      28         finally:
#      29             self.close()
#
# ~\anaconda3\lib\site-packages\pandas_datareader\fred.py in _read(self)
#      60
#      61         df = concat(
# ---> 62             [fetch_data(url, n) for url, n in zip(urls, names)], axis=1, join="outer"
#      63         )
#      64         return df
#
# ...

# %%
import pandas_datareader.data as web

# %%
df = web.DataReader('GE', 'yahoo', start='2019-09-10', end='2019-10-09')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_608/3747569027.py in <module>
# ----> 1 df = web.DataReader('GE', 'yahoo', start='2019-09-10', end='2019-10-09')
#
# ~\anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     205                 else:
#     206                     kwargs[new_arg_name] = new_arg_value
# --> 207             return func(*args, **kwargs)
#     208
#     209         return cast(F, wrapper)
#
# ~\anaconda3\lib\site-packages\pandas_datareader\data.py in DataReader(name, data_source, start, end, retry_count, pause, session, api_key)
#     368
#     369     if data_source == "yahoo":
# --> 370         return YahooDailyReader(
#     371             symbols=name,
#     372             start=start,
#
# ~\anaconda3\lib\site-packages\pandas_datareader\base.py in read(self)
# ...

# %%
df = pd.read_csv('TSLA.csv')
df.head()
# Out:
#          Date       Open       High        Low      Close     Volume  \
# 0  2019-05-21  39.551998  41.480000  39.208000  41.015999   90019500
# 1  2019-05-22  39.820000  40.787998  38.355999  38.546001   93426000
# 2  2019-05-23  38.868000  39.894001  37.243999  39.098000  132735500
# 3  2019-05-24  39.966000  39.995998  37.750000  38.125999   70683000
# 4  2019-05-28  38.240002  39.000000  37.570000  37.740002   51564500
#
#    Dividends  Stock Splits
# 0          0           0.0
# 1          0           0.0
# 2          0           0.0
# 3          0           0.0
# 4          0           0.0

# %%
df = df.set_index('Date')

# %%
df
# Out:
#                   Open        High         Low       Close     Volume  \
# Date
# 2019-05-21   39.551998   41.480000   39.208000   41.015999   90019500
# 2019-05-22   39.820000   40.787998   38.355999   38.546001   93426000
# 2019-05-23   38.868000   39.894001   37.243999   39.098000  132735500
# 2019-05-24   39.966000   39.995998   37.750000   38.125999   70683000
# 2019-05-28   38.240002   39.000000   37.570000   37.740002   51564500
# ...                ...         ...         ...         ...        ...
# 2022-05-16  767.159973  769.760010  719.090027  724.369995   28699500
# 2022-05-17  747.359985  764.479980  728.849976  761.609985   26745400
# 2022-05-18  744.520020  760.500000  700.809998  709.809998   29270600
# 2022-05-19  707.000000  734.000000  694.109985  709.419983   30098900
# 2022-05-20  713.989990  721.580017  633.000000  663.900024   48190600
#
#             Dividends  Stock Splits
# Date
# 2019-05-21          0           0.0
# 2019-05-22          0           0.0
# ...

# %%
df.plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
df.columns
# Out:
# Index(['Open', 'High', 'Low', 'Close', 'Volume', 'Dividends', 'Stock Splits'], dtype='object')

# %%
df['High'].plot(figsize=(12,6))
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
df['High'].plot(ylim=[0,900],figsize=(12,4))
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
df['High'].plot(ylim=[0,900],figsize=(12,4))
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
df['High'].plot(ylim=[0,1000],figsize=(12,4),ls='--',c='green')
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
df.index
# Out:
# Index(['2019-05-21', '2019-05-22', '2019-05-23', '2019-05-24', '2019-05-28',
#        '2019-05-29', '2019-05-30', '2019-05-31', '2019-06-03', '2019-06-04',
#        ...
#        '2022-05-09', '2022-05-10', '2022-05-11', '2022-05-12', '2022-05-13',
#        '2022-05-16', '2022-05-17', '2022-05-18', '2022-05-19', '2022-05-20'],
#       dtype='object', name='Date', length=758)

# %%
index = df.loc['2020-01-01':'2021-09-01'].index
share_open = df.loc['2020-01-01':'2021-09-01']['Open']

# %%
share_open
# Out:
# Date
# 2020-01-02     84.900002
# 2020-01-03     88.099998
# 2020-01-06     88.094002
# 2020-01-07     92.279999
# 2020-01-08     94.739998
#                  ...
# 2021-08-26    708.309998
# 2021-08-27    705.000000
# 2021-08-30    714.719971
# 2021-08-31    733.000000
# 2021-09-01    734.080017
# Name: Open, Length: 421, dtype: float64

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
figure,axis = plt.subplots()
plt.tight_layout()
figure.autofmt_xdate()
axis.plot(index,share_open)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 758 entries, 2019-05-21 to 2022-05-20
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Open          758 non-null    float64
#  1   High          758 non-null    float64
#  2   Low           758 non-null    float64
#  3   Close         758 non-null    float64
#  4   Volume        758 non-null    int64
#  5   Dividends     758 non-null    int64
#  6   Stock Splits  758 non-null    float64
# dtypes: float64(5), int64(2)
# memory usage: 63.5+ KB

# %%
df
# Out:
#                   Open        High         Low       Close     Volume  \
# Date
# 2019-05-21   39.551998   41.480000   39.208000   41.015999   90019500
# 2019-05-22   39.820000   40.787998   38.355999   38.546001   93426000
# 2019-05-23   38.868000   39.894001   37.243999   39.098000  132735500
# 2019-05-24   39.966000   39.995998   37.750000   38.125999   70683000
# 2019-05-28   38.240002   39.000000   37.570000   37.740002   51564500
# ...                ...         ...         ...         ...        ...
# 2022-05-16  767.159973  769.760010  719.090027  724.369995   28699500
# 2022-05-17  747.359985  764.479980  728.849976  761.609985   26745400
# 2022-05-18  744.520020  760.500000  700.809998  709.809998   29270600
# 2022-05-19  707.000000  734.000000  694.109985  709.419983   30098900
# 2022-05-20  713.989990  721.580017  633.000000  663.900024   48190600
#
#             Dividends  Stock Splits
# Date
# 2019-05-21          0           0.0
# 2019-05-22          0           0.0
# ...

# %%
df = pd.read_csv('TSLA.csv',parse_dates=['Date'])
df
# Out:
#           Date        Open        High         Low       Close     Volume  \
# 0   2019-05-21   39.551998   41.480000   39.208000   41.015999   90019500
# 1   2019-05-22   39.820000   40.787998   38.355999   38.546001   93426000
# 2   2019-05-23   38.868000   39.894001   37.243999   39.098000  132735500
# 3   2019-05-24   39.966000   39.995998   37.750000   38.125999   70683000
# 4   2019-05-28   38.240002   39.000000   37.570000   37.740002   51564500
# ..         ...         ...         ...         ...         ...        ...
# 753 2022-05-16  767.159973  769.760010  719.090027  724.369995   28699500
# 754 2022-05-17  747.359985  764.479980  728.849976  761.609985   26745400
# 755 2022-05-18  744.520020  760.500000  700.809998  709.809998   29270600
# 756 2022-05-19  707.000000  734.000000  694.109985  709.419983   30098900
# 757 2022-05-20  713.989990  721.580017  633.000000  663.900024   48190600
#
#      Dividends  Stock Splits
# 0            0           0.0
# ...

# %%
df = df.set_index('Date',drop=True)
df
# Out:
#                   Open        High         Low       Close     Volume  \
# Date
# 2019-05-21   39.551998   41.480000   39.208000   41.015999   90019500
# 2019-05-22   39.820000   40.787998   38.355999   38.546001   93426000
# 2019-05-23   38.868000   39.894001   37.243999   39.098000  132735500
# 2019-05-24   39.966000   39.995998   37.750000   38.125999   70683000
# 2019-05-28   38.240002   39.000000   37.570000   37.740002   51564500
# ...                ...         ...         ...         ...        ...
# 2022-05-16  767.159973  769.760010  719.090027  724.369995   28699500
# 2022-05-17  747.359985  764.479980  728.849976  761.609985   26745400
# 2022-05-18  744.520020  760.500000  700.809998  709.809998   29270600
# 2022-05-19  707.000000  734.000000  694.109985  709.419983   30098900
# 2022-05-20  713.989990  721.580017  633.000000  663.900024   48190600
#
#             Dividends  Stock Splits
# Date
# 2019-05-21          0           0.0
# 2019-05-22          0           0.0
# ...

# %%
df.resample(rule='A').min()
# Out:
#                   Open        High         Low       Close    Volume  \
# Date
# 2019-12-31   36.220001   37.335999   35.397999   35.793999  12328000
# 2020-12-31   74.940002   80.972000   70.101997   72.244003  17357700
# 2021-12-31  552.549988  566.210022  539.489990  563.000000   9800600
# 2022-12-31  700.390015  721.580017  633.000000  663.900024  16330900
#
#             Dividends  Stock Splits
# Date
# 2019-12-31          0           0.0
# 2020-12-31          0           0.0
# 2021-12-31          0           0.0
# 2022-12-31          0           0.0

# %%
df.resample(rule='A').max()
# Out:
#                    Open         High          Low        Close     Volume  \
# Date
# 2019-12-31    87.000000    87.061996    85.269997    86.188004  150030500
# 2020-12-31   699.989990   718.719971   691.119995   705.669983  304694000
# 2021-12-31  1234.410034  1243.489990  1217.000000  1229.910034   89396500
# 2022-12-31  1189.550049  1208.000000  1136.040039  1199.780029   50521900
#
#             Dividends  Stock Splits
# Date
# 2019-12-31          0           0.0
# 2020-12-31          0           5.0
# 2021-12-31          0           0.0
# 2022-12-31          0           0.0

# %%
##year end frequency
df.resample(rule='A').max()['Open'].plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
##quaterly start frequency
##https://towardsdatascience.com/resample-function-of-pandas-79b17ec82a78
df.resample(rule='QS').max()['High'].plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
##Business End Frequency
##https://towardsdatascience.com/resample-function-of-pandas-79b17ec82a78
df.resample(rule='BA').max()
# Out:
#                    Open         High          Low        Close     Volume  \
# Date
# 2019-12-31    87.000000    87.061996    85.269997    86.188004  150030500
# 2020-12-31   699.989990   718.719971   691.119995   705.669983  304694000
# 2021-12-31  1234.410034  1243.489990  1217.000000  1229.910034   89396500
# 2022-12-30  1189.550049  1208.000000  1136.040039  1199.780029   50521900
#
#             Dividends  Stock Splits
# Date
# 2019-12-31          0           0.0
# 2020-12-31          0           5.0
# 2021-12-31          0           0.0
# 2022-12-30          0           0.0

# %%
df.resample(rule='BQS').max()
# Out:
#                    Open         High          Low        Close     Volume  \
# Date
# 2019-04-01    45.743999    46.948002    44.512001    45.285999  132735500
# 2019-07-01    51.834000    53.214001    51.632000    52.976002  112091500
# 2019-10-01    87.000000    87.061996    85.269997    86.188004  150030500
# 2020-01-01   184.699997   193.798004   180.203995   183.483994  304694000
# 2020-04-01   202.556000   217.537994   200.746002   215.962006  162659000
# 2020-07-01   502.140015   502.489990   470.510010   498.320007  194927000
# 2020-10-01   699.989990   718.719971   691.119995   705.669983  222126200
# 2021-01-01   891.380005   900.400024   871.599976   883.090027   89396500
# 2021-04-01   770.700012   780.789978   732.609985   762.320007   49017400
# 2021-07-01   787.200012   799.000000   775.000000   791.359985   33615800
# 2021-10-01  1234.410034  1243.489990  1217.000000  1229.910034   62852100
# 2022-01-03  1189.550049  1208.000000  1136.040039  1199.780029   50521900
# ...

# %%
##plotting
df['Open'].resample(rule='A').mean().plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
df['Open'].resample(rule='M').max().plot(kind='bar',figsize=(15,6))
# Out:
# <AxesSubplot:xlabel='Date'>
